# %% [markdown]
# # Parsing de Fechas
#
# En este JNB se revisará el tema de Parsing de Fechas.

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
# modules we'll use
import pandas as pd
import numpy as np
import seaborn as sns
import datetime

# read in our data
landslides = pd.read_csv("./data/catalog.txt")

# set seed for reproducibility
np.random.seed(0)

# %%
landslides.head(23)
# Out:
#      id     date   time continent_code        country_name country_code  \
# 0    34   3/2/07  Night            NaN       United States           US
# 1    42  3/22/07    NaN            NaN       United States           US
# 2    56   4/6/07    NaN            NaN       United States           US
# 3    59  4/14/07    NaN            NaN              Canada           CA
# 4    61  4/15/07    NaN            NaN       United States           US
# 5    64  4/20/07    NaN            NaN       United States           US
# 6    67  4/24/07    NaN            NaN       United States           US
# 7    77  5/21/07    NaN             SA            Colombia           CO
# 8   105  6/27/07    NaN             SA             Ecuador           EC
# 9   106  6/27/07    NaN             SA             Ecuador           EC
# 10  107  6/27/07    NaN             SA             Ecuador           EC
# 11  109   7/1/07    NaN            NaN       United States           US
# 12  115   7/4/07    NaN            NaN              Mexico           MX
# 13  119   7/8/07    NaN            NaN              Canada           CA
# 14  124  7/13/07  Night            NaN  Dominican Republic           DO
# 15  138  7/24/07    NaN            NaN       United States           US
# 16  165   8/9/07    NaN            NaN           Guatemala           GT
# 17  174  8/11/07    NaN            NaN             Jamaica           JM
# 18  185  8/14/07    NaN            NaN       United States           US
# 19  186  8/17/07    NaN            NaN            Dominica           DM
# 20  187  8/18/07    NaN            NaN       United States           US
# 21  188  8/18/07    NaN            NaN       United States           US
# 22  189  8/18/07    NaN            NaN       United States           US
#
#        state/province  population                    city/town  distance  ...  \
# 0            Virginia       16000                  Cherry Hill   3.40765  ...
# 1                Ohio       17288             New Philadelphia   3.33522  ...
# 2        Pennsylvania       15930                  Wilkinsburg   2.91977  ...
# 3              Quebec       42786                  Châteauguay   2.98682  ...
# 4            Kentucky        6903                    Pikeville   5.66542  ...
# 5            Kentucky        6903                    Pikeville   0.23715  ...
# 6        South Dakota        2540                 Dakota Dunes   2.48033  ...
# 7           Risaralda      440118                      Pereira   0.62022  ...
# 8    Zamora-Chinchipe       15276                       Zamora   0.47714  ...
# 9                Loja      117796                         Loja   0.35649  ...
# 10          Pichincha        5114                    Sangolquí  33.94603  ...
# 11              Texas       42409                  Haltom City   0.03668  ...
# 12     Veracruz-Llave        1947  Laguna Chica (Pueblo Nuevo)   9.51003  ...
# 13            Ontario      812129                       Ottawa   1.74759  ...
# 14  Distrito Nacional       13456                   San Carlos   1.70298  ...
# 15              Texas      175396                Grand Prairie   5.66936  ...
# 16          Guatemala       47247              San José Pinula   4.74385  ...
# 17           Portland       14400                 Port Antonio   7.79027  ...
# 18           Colorado        2475                       Meeker  10.87949  ...
# 19         Saint Paul         702                   Pont Cassé   3.39516  ...
# 20          Minnesota        2868                    Caledonia  22.31062  ...
# 21            Wyoming        9520                         Cody  64.74594  ...
# 22          Minnesota      106769                    Rochester   0.99990  ...
#
#                                     geolocation  hazard_type  \
# 0     (38.600900000000003, -77.268199999999993)    Landslide
# 1     (40.517499999999998, -81.430499999999995)    Landslide
# 2                (40.4377, -79.915999999999997)    Landslide
# 3     (45.322600000000001, -73.777100000000004)    Landslide
# 4     (37.432499999999997, -82.493099999999998)    Landslide
# 5     (37.481400000000001, -82.518600000000006)    Landslide
# 6     (42.494100000000003, -96.457599999999999)    Landslide
# 7     (4.8080999999999996, -75.694100000000006)    Landslide
# 8    (-4.0650000000000004, -78.950999999999993)    Landslide
# 9                  (-3.99, -79.204999999999998)    Landslide
# 10  (-0.35599999999999998, -78.147999999999996)    Landslide
# 11    (32.799500000000002, -97.268799999999999)    Landslide
# 12    (18.536899999999999, -96.822900000000004)    Landslide
# 13    (45.425699999999999, -75.689599999999999)    Landslide
# 14               (18.4757, -69.914000000000001)    Landslide
# 15               (32.7883, -97.031700000000001)    Landslide
# 16                 (14.566700000000001, -90.45)    Landslide
# 17    (18.125800000000002, -76.508200000000002)    Landslide
# 18              (39.942500000000003, -107.8818)    Landslide
# 19    (15.337899999999999, -61.360999999999997)    Landslide
# 20               (43.595999999999997, -91.2256)    Landslide
# 21    (44.465899999999998, -109.86620000000001)    Landslide
# 22               (44.0304, -92.467100000000002)    Landslide
#
#         landslide_type landslide_size           trigger      storm_name  \
# 0            Landslide          Small              Rain             NaN
# 1            Landslide          Small              Rain             NaN
# 2            Landslide          Small              Rain             NaN
# 3   Riverbank collapse          Small              Rain             NaN
# 4            Landslide          Small          Downpour             NaN
# 5            Landslide          Small              Rain             NaN
# 6            Landslide          Small              Rain             NaN
# 7             Mudslide          Large              Rain             NaN
# 8            Landslide         Medium          Downpour             NaN
# 9            Landslide         Medium          Downpour             NaN
# 10           Landslide         Medium          Downpour             NaN
# 11           Landslide         Medium              Rain             NaN
# 12           Landslide         Medium              Rain             NaN
# 13           Landslide          Small           Unknown             NaN
# 14           Landslide          Small           Unknown             NaN
# 15           Landslide          Small              Rain             NaN
# 16            Mudslide         Medium              Rain             NaN
# 17           Landslide         Medium              Rain             NaN
# 18            Mudslide         Medium              Rain             NaN
# 19            Mudslide          Small  Tropical cyclone  Hurricane Dean
# 20           Landslide         Medium              Rain             NaN
# 21           Landslide          Small              Rain             NaN
# 22            Mudslide          Small              Rain             NaN
#
#    injuries fatalities                                   source_name  \
# 0       NaN        NaN                                    NBC 4 news
# 1       NaN        NaN                                Canton Rep.com
# 2       NaN        NaN                    The Pittsburgh Channel.com
# 3       NaN        NaN                                     Le Soleil
# 4       NaN        0.0                        Matthew Crawford (KGS)
# 5       NaN        NaN                     Applalachain news-express
# 6       NaN        NaN                           Sioux City Journnal
# 7       NaN       13.0                        Reuters - AlertNet.org
# 8       NaN        NaN                     Red Cross - Field reports
# 9       NaN        NaN                     Red Cross - Field reports
# 10      NaN        NaN                     Red Cross - Field reports
# 11      NaN        NaN                                     NBC5i.com
# 12      NaN        7.0                                   nytimes.com
# 13      NaN        NaN                                           NaN
# 14      NaN        NaN                               Dominican Today
# 15      NaN        NaN  Trinity River Authority - Grand Prarie Times
# 16      NaN        5.0                          International Herald
# 17      NaN        NaN                               Jamaica Gleaner
# 18      NaN        NaN                        Telluride Daily Planet
# 19      NaN        2.0                                 Tribune India
# 20      NaN        NaN                                 The Sun Times
# 21      NaN        NaN                              Billings Gazette
# 22      NaN        NaN                             Post bulletin.com
#
#                                           source_link
# 0       http://www.nbc4.com/news/11186871/detail.html
# 1   http://www.cantonrep.com/index.php?ID=345054&C...
# 2   https://web.archive.org/web/20080423132842/htt...
# 3   http://www.hebdos.net/lsc/edition162007/articl...
# 4                                                 NaN
# 5   http://www.news-expressky.com/articles/2007/04...
# 6   http://www.siouxcityjournal.com/articles/2007/...
# 7   http://www.reuters.com/news/video/videoStory?v...
# 8   https://www-secure.ifrc.org/dmis/prepare/view_...
# 9   https://www-secure.ifrc.org/dmis/prepare/view_...
# 10  https://www-secure.ifrc.org/dmis/prepare/view_...
# 11     http://www.nbc5i.com/news/13604036/detail.html
# 12  http://www.nytimes.com/2007/07/04/world/americ...
# 13  http://www.cfra.com/headlines/index.asp?cat=1&...
# 14  http://www.dominicantoday.com/app/article.aspx...
# 15  http://www.gptimes.com/?story_20070627130646_s...
# 16  http://www.iht.com/articles/ap/2007/08/09/amer...
# 17  http://www.jamaica-gleaner.com/gleaner/2007081...
# 18  http://www.telluridegateway.com/articles/2007/...
# 19  http://www.tribuneindia.com/2007/20070817/hima...
# 20  http://www.suntimes.com/news/nation/516414,19f...
# 21  http://www.billingsgazette.net/articles/2007/0...
# 22  http://www.postbulletin.com/newsmanager/templa...
#
# [23 rows x 23 columns]

# %%
# print the first few rows of the date column
print(landslides['date'].head())
# Out:
# 0     3/2/07
# 1    3/22/07
# 2     4/6/07
# 3    4/14/07
# 4    4/15/07
# Name: date, dtype: object

# %%
landslides.dtypes
# Out:
# id                        int64
# date                     object
# time                     object
# continent_code           object
# country_name             object
# country_code             object
# state/province           object
# population                int64
# city/town                object
# distance                float64
# location_description     object
# latitude                float64
# longitude               float64
# geolocation              object
# hazard_type              object
# landslide_type           object
# landslide_size           object
# trigger                  object
# storm_name               object
# injuries                float64
# fatalities              float64
# source_name              object
# source_link              object
# dtype: object

# %%
# create a new column, date_parsed, with the parsed dates
landslides['date_parsed'] = pd.to_datetime(landslides['date'], format="%m/%d/%y")

# %%
landslides.head(23)
# Out:
#      id     date   time continent_code        country_name country_code  \
# 0    34   3/2/07  Night            NaN       United States           US
# 1    42  3/22/07    NaN            NaN       United States           US
# 2    56   4/6/07    NaN            NaN       United States           US
# 3    59  4/14/07    NaN            NaN              Canada           CA
# 4    61  4/15/07    NaN            NaN       United States           US
# 5    64  4/20/07    NaN            NaN       United States           US
# 6    67  4/24/07    NaN            NaN       United States           US
# 7    77  5/21/07    NaN             SA            Colombia           CO
# 8   105  6/27/07    NaN             SA             Ecuador           EC
# 9   106  6/27/07    NaN             SA             Ecuador           EC
# 10  107  6/27/07    NaN             SA             Ecuador           EC
# 11  109   7/1/07    NaN            NaN       United States           US
# 12  115   7/4/07    NaN            NaN              Mexico           MX
# 13  119   7/8/07    NaN            NaN              Canada           CA
# 14  124  7/13/07  Night            NaN  Dominican Republic           DO
# 15  138  7/24/07    NaN            NaN       United States           US
# 16  165   8/9/07    NaN            NaN           Guatemala           GT
# 17  174  8/11/07    NaN            NaN             Jamaica           JM
# 18  185  8/14/07    NaN            NaN       United States           US
# 19  186  8/17/07    NaN            NaN            Dominica           DM
# 20  187  8/18/07    NaN            NaN       United States           US
# 21  188  8/18/07    NaN            NaN       United States           US
# 22  189  8/18/07    NaN            NaN       United States           US
#
#        state/province  population                    city/town  distance  ...  \
# 0            Virginia       16000                  Cherry Hill   3.40765  ...
# 1                Ohio       17288             New Philadelphia   3.33522  ...
# 2        Pennsylvania       15930                  Wilkinsburg   2.91977  ...
# 3              Quebec       42786                  Châteauguay   2.98682  ...
# 4            Kentucky        6903                    Pikeville   5.66542  ...
# 5            Kentucky        6903                    Pikeville   0.23715  ...
# 6        South Dakota        2540                 Dakota Dunes   2.48033  ...
# 7           Risaralda      440118                      Pereira   0.62022  ...
# 8    Zamora-Chinchipe       15276                       Zamora   0.47714  ...
# 9                Loja      117796                         Loja   0.35649  ...
# 10          Pichincha        5114                    Sangolquí  33.94603  ...
# 11              Texas       42409                  Haltom City   0.03668  ...
# 12     Veracruz-Llave        1947  Laguna Chica (Pueblo Nuevo)   9.51003  ...
# 13            Ontario      812129                       Ottawa   1.74759  ...
# 14  Distrito Nacional       13456                   San Carlos   1.70298  ...
# 15              Texas      175396                Grand Prairie   5.66936  ...
# 16          Guatemala       47247              San José Pinula   4.74385  ...
# 17           Portland       14400                 Port Antonio   7.79027  ...
# 18           Colorado        2475                       Meeker  10.87949  ...
# 19         Saint Paul         702                   Pont Cassé   3.39516  ...
# 20          Minnesota        2868                    Caledonia  22.31062  ...
# 21            Wyoming        9520                         Cody  64.74594  ...
# 22          Minnesota      106769                    Rochester   0.99990  ...
#
#    hazard_type      landslide_type  landslide_size           trigger  \
# 0    Landslide           Landslide           Small              Rain
# 1    Landslide           Landslide           Small              Rain
# 2    Landslide           Landslide           Small              Rain
# 3    Landslide  Riverbank collapse           Small              Rain
# 4    Landslide           Landslide           Small          Downpour
# 5    Landslide           Landslide           Small              Rain
# 6    Landslide           Landslide           Small              Rain
# 7    Landslide            Mudslide           Large              Rain
# 8    Landslide           Landslide          Medium          Downpour
# 9    Landslide           Landslide          Medium          Downpour
# 10   Landslide           Landslide          Medium          Downpour
# 11   Landslide           Landslide          Medium              Rain
# 12   Landslide           Landslide          Medium              Rain
# 13   Landslide           Landslide           Small           Unknown
# 14   Landslide           Landslide           Small           Unknown
# 15   Landslide           Landslide           Small              Rain
# 16   Landslide            Mudslide          Medium              Rain
# 17   Landslide           Landslide          Medium              Rain
# 18   Landslide            Mudslide          Medium              Rain
# 19   Landslide            Mudslide           Small  Tropical cyclone
# 20   Landslide           Landslide          Medium              Rain
# 21   Landslide           Landslide           Small              Rain
# 22   Landslide            Mudslide           Small              Rain
#
#         storm_name injuries fatalities  \
# 0              NaN      NaN        NaN
# 1              NaN      NaN        NaN
# 2              NaN      NaN        NaN
# 3              NaN      NaN        NaN
# 4              NaN      NaN        0.0
# 5              NaN      NaN        NaN
# 6              NaN      NaN        NaN
# 7              NaN      NaN       13.0
# 8              NaN      NaN        NaN
# 9              NaN      NaN        NaN
# 10             NaN      NaN        NaN
# 11             NaN      NaN        NaN
# 12             NaN      NaN        7.0
# 13             NaN      NaN        NaN
# 14             NaN      NaN        NaN
# 15             NaN      NaN        NaN
# 16             NaN      NaN        5.0
# 17             NaN      NaN        NaN
# 18             NaN      NaN        NaN
# 19  Hurricane Dean      NaN        2.0
# 20             NaN      NaN        NaN
# 21             NaN      NaN        NaN
# 22             NaN      NaN        NaN
#
#                                      source_name  \
# 0                                     NBC 4 news
# 1                                 Canton Rep.com
# 2                     The Pittsburgh Channel.com
# 3                                      Le Soleil
# 4                         Matthew Crawford (KGS)
# 5                      Applalachain news-express
# 6                            Sioux City Journnal
# 7                         Reuters - AlertNet.org
# 8                      Red Cross - Field reports
# 9                      Red Cross - Field reports
# 10                     Red Cross - Field reports
# 11                                     NBC5i.com
# 12                                   nytimes.com
# 13                                           NaN
# 14                               Dominican Today
# 15  Trinity River Authority - Grand Prarie Times
# 16                          International Herald
# 17                               Jamaica Gleaner
# 18                        Telluride Daily Planet
# 19                                 Tribune India
# 20                                 The Sun Times
# 21                              Billings Gazette
# 22                             Post bulletin.com
#
#                                           source_link  date_parsed
# 0       http://www.nbc4.com/news/11186871/detail.html   2007-03-02
# 1   http://www.cantonrep.com/index.php?ID=345054&C...   2007-03-22
# 2   https://web.archive.org/web/20080423132842/htt...   2007-04-06
# 3   http://www.hebdos.net/lsc/edition162007/articl...   2007-04-14
# 4                                                 NaN   2007-04-15
# 5   http://www.news-expressky.com/articles/2007/04...   2007-04-20
# 6   http://www.siouxcityjournal.com/articles/2007/...   2007-04-24
# 7   http://www.reuters.com/news/video/videoStory?v...   2007-05-21
# 8   https://www-secure.ifrc.org/dmis/prepare/view_...   2007-06-27
# 9   https://www-secure.ifrc.org/dmis/prepare/view_...   2007-06-27
# 10  https://www-secure.ifrc.org/dmis/prepare/view_...   2007-06-27
# 11     http://www.nbc5i.com/news/13604036/detail.html   2007-07-01
# 12  http://www.nytimes.com/2007/07/04/world/americ...   2007-07-04
# 13  http://www.cfra.com/headlines/index.asp?cat=1&...   2007-07-08
# 14  http://www.dominicantoday.com/app/article.aspx...   2007-07-13
# 15  http://www.gptimes.com/?story_20070627130646_s...   2007-07-24
# 16  http://www.iht.com/articles/ap/2007/08/09/amer...   2007-08-09
# 17  http://www.jamaica-gleaner.com/gleaner/2007081...   2007-08-11
# 18  http://www.telluridegateway.com/articles/2007/...   2007-08-14
# 19  http://www.tribuneindia.com/2007/20070817/hima...   2007-08-17
# 20  http://www.suntimes.com/news/nation/516414,19f...   2007-08-18
# 21  http://www.billingsgazette.net/articles/2007/0...   2007-08-18
# 22  http://www.postbulletin.com/newsmanager/templa...   2007-08-18
#
# [23 rows x 24 columns]

# %%
landslides.dtypes
# Out:
# id                               int64
# date                            object
# time                            object
# continent_code                  object
# country_name                    object
# country_code                    object
# state/province                  object
# population                       int64
# city/town                       object
# distance                       float64
# location_description            object
# latitude                       float64
# longitude                      float64
# geolocation                     object
# hazard_type                     object
# landslide_type                  object
# landslide_size                  object
# trigger                         object
# storm_name                      object
# injuries                       float64
# fatalities                     float64
# source_name                     object
# source_link                     object
# date_parsed             datetime64[ns]
# dtype: object

# %%
landslides['date2'] = pd.to_datetime(landslides['date'], infer_datetime_format=True)

# %%
landslides.head(23)
# Out:
#      id     date   time continent_code        country_name country_code  \
# 0    34   3/2/07  Night            NaN       United States           US
# 1    42  3/22/07    NaN            NaN       United States           US
# 2    56   4/6/07    NaN            NaN       United States           US
# 3    59  4/14/07    NaN            NaN              Canada           CA
# 4    61  4/15/07    NaN            NaN       United States           US
# 5    64  4/20/07    NaN            NaN       United States           US
# 6    67  4/24/07    NaN            NaN       United States           US
# 7    77  5/21/07    NaN             SA            Colombia           CO
# 8   105  6/27/07    NaN             SA             Ecuador           EC
# 9   106  6/27/07    NaN             SA             Ecuador           EC
# 10  107  6/27/07    NaN             SA             Ecuador           EC
# 11  109   7/1/07    NaN            NaN       United States           US
# 12  115   7/4/07    NaN            NaN              Mexico           MX
# 13  119   7/8/07    NaN            NaN              Canada           CA
# 14  124  7/13/07  Night            NaN  Dominican Republic           DO
# 15  138  7/24/07    NaN            NaN       United States           US
# 16  165   8/9/07    NaN            NaN           Guatemala           GT
# 17  174  8/11/07    NaN            NaN             Jamaica           JM
# 18  185  8/14/07    NaN            NaN       United States           US
# 19  186  8/17/07    NaN            NaN            Dominica           DM
# 20  187  8/18/07    NaN            NaN       United States           US
# 21  188  8/18/07    NaN            NaN       United States           US
# 22  189  8/18/07    NaN            NaN       United States           US
#
#        state/province  population                    city/town  distance  ...  \
# 0            Virginia       16000                  Cherry Hill   3.40765  ...
# 1                Ohio       17288             New Philadelphia   3.33522  ...
# 2        Pennsylvania       15930                  Wilkinsburg   2.91977  ...
# 3              Quebec       42786                  Châteauguay   2.98682  ...
# 4            Kentucky        6903                    Pikeville   5.66542  ...
# 5            Kentucky        6903                    Pikeville   0.23715  ...
# 6        South Dakota        2540                 Dakota Dunes   2.48033  ...
# 7           Risaralda      440118                      Pereira   0.62022  ...
# 8    Zamora-Chinchipe       15276                       Zamora   0.47714  ...
# 9                Loja      117796                         Loja   0.35649  ...
# 10          Pichincha        5114                    Sangolquí  33.94603  ...
# 11              Texas       42409                  Haltom City   0.03668  ...
# 12     Veracruz-Llave        1947  Laguna Chica (Pueblo Nuevo)   9.51003  ...
# 13            Ontario      812129                       Ottawa   1.74759  ...
# 14  Distrito Nacional       13456                   San Carlos   1.70298  ...
# 15              Texas      175396                Grand Prairie   5.66936  ...
# 16          Guatemala       47247              San José Pinula   4.74385  ...
# 17           Portland       14400                 Port Antonio   7.79027  ...
# 18           Colorado        2475                       Meeker  10.87949  ...
# 19         Saint Paul         702                   Pont Cassé   3.39516  ...
# 20          Minnesota        2868                    Caledonia  22.31062  ...
# 21            Wyoming        9520                         Cody  64.74594  ...
# 22          Minnesota      106769                    Rochester   0.99990  ...
#
#         landslide_type  landslide_size           trigger      storm_name  \
# 0            Landslide           Small              Rain             NaN
# 1            Landslide           Small              Rain             NaN
# 2            Landslide           Small              Rain             NaN
# 3   Riverbank collapse           Small              Rain             NaN
# 4            Landslide           Small          Downpour             NaN
# 5            Landslide           Small              Rain             NaN
# 6            Landslide           Small              Rain             NaN
# 7             Mudslide           Large              Rain             NaN
# 8            Landslide          Medium          Downpour             NaN
# 9            Landslide          Medium          Downpour             NaN
# 10           Landslide          Medium          Downpour             NaN
# 11           Landslide          Medium              Rain             NaN
# 12           Landslide          Medium              Rain             NaN
# 13           Landslide           Small           Unknown             NaN
# 14           Landslide           Small           Unknown             NaN
# 15           Landslide           Small              Rain             NaN
# 16            Mudslide          Medium              Rain             NaN
# 17           Landslide          Medium              Rain             NaN
# 18            Mudslide          Medium              Rain             NaN
# 19            Mudslide           Small  Tropical cyclone  Hurricane Dean
# 20           Landslide          Medium              Rain             NaN
# 21           Landslide           Small              Rain             NaN
# 22            Mudslide           Small              Rain             NaN
#
#    injuries fatalities                                   source_name  \
# 0       NaN        NaN                                    NBC 4 news
# 1       NaN        NaN                                Canton Rep.com
# 2       NaN        NaN                    The Pittsburgh Channel.com
# 3       NaN        NaN                                     Le Soleil
# 4       NaN        0.0                        Matthew Crawford (KGS)
# 5       NaN        NaN                     Applalachain news-express
# 6       NaN        NaN                           Sioux City Journnal
# 7       NaN       13.0                        Reuters - AlertNet.org
# 8       NaN        NaN                     Red Cross - Field reports
# 9       NaN        NaN                     Red Cross - Field reports
# 10      NaN        NaN                     Red Cross - Field reports
# 11      NaN        NaN                                     NBC5i.com
# 12      NaN        7.0                                   nytimes.com
# 13      NaN        NaN                                           NaN
# 14      NaN        NaN                               Dominican Today
# 15      NaN        NaN  Trinity River Authority - Grand Prarie Times
# 16      NaN        5.0                          International Herald
# 17      NaN        NaN                               Jamaica Gleaner
# 18      NaN        NaN                        Telluride Daily Planet
# 19      NaN        2.0                                 Tribune India
# 20      NaN        NaN                                 The Sun Times
# 21      NaN        NaN                              Billings Gazette
# 22      NaN        NaN                             Post bulletin.com
#
#                                           source_link date_parsed      date2
# 0       http://www.nbc4.com/news/11186871/detail.html  2007-03-02 2007-03-02
# 1   http://www.cantonrep.com/index.php?ID=345054&C...  2007-03-22 2007-03-22
# 2   https://web.archive.org/web/20080423132842/htt...  2007-04-06 2007-04-06
# 3   http://www.hebdos.net/lsc/edition162007/articl...  2007-04-14 2007-04-14
# 4                                                 NaN  2007-04-15 2007-04-15
# 5   http://www.news-expressky.com/articles/2007/04...  2007-04-20 2007-04-20
# 6   http://www.siouxcityjournal.com/articles/2007/...  2007-04-24 2007-04-24
# 7   http://www.reuters.com/news/video/videoStory?v...  2007-05-21 2007-05-21
# 8   https://www-secure.ifrc.org/dmis/prepare/view_...  2007-06-27 2007-06-27
# 9   https://www-secure.ifrc.org/dmis/prepare/view_...  2007-06-27 2007-06-27
# 10  https://www-secure.ifrc.org/dmis/prepare/view_...  2007-06-27 2007-06-27
# 11     http://www.nbc5i.com/news/13604036/detail.html  2007-07-01 2007-07-01
# 12  http://www.nytimes.com/2007/07/04/world/americ...  2007-07-04 2007-07-04
# 13  http://www.cfra.com/headlines/index.asp?cat=1&...  2007-07-08 2007-07-08
# 14  http://www.dominicantoday.com/app/article.aspx...  2007-07-13 2007-07-13
# 15  http://www.gptimes.com/?story_20070627130646_s...  2007-07-24 2007-07-24
# 16  http://www.iht.com/articles/ap/2007/08/09/amer...  2007-08-09 2007-08-09
# 17  http://www.jamaica-gleaner.com/gleaner/2007081...  2007-08-11 2007-08-11
# 18  http://www.telluridegateway.com/articles/2007/...  2007-08-14 2007-08-14
# 19  http://www.tribuneindia.com/2007/20070817/hima...  2007-08-17 2007-08-17
# 20  http://www.suntimes.com/news/nation/516414,19f...  2007-08-18 2007-08-18
# 21  http://www.billingsgazette.net/articles/2007/0...  2007-08-18 2007-08-18
# 22  http://www.postbulletin.com/newsmanager/templa...  2007-08-18 2007-08-18
#
# [23 rows x 25 columns]

# %%
# get the day of the month from the date_parsed column
day_of_month_landslides = landslides['date_parsed'].dt.day
day_of_month_landslides.head()
# Out:
# 0     2.0
# 1    22.0
# 2     6.0
# 3    14.0
# 4    15.0
# Name: date_parsed, dtype: float64

# %%
# remove na's
day_of_month_landslides = day_of_month_landslides.dropna()

# plot the day of the month
sns.distplot(day_of_month_landslides, kde=False, bins=31)
# Out:
# /tmp/ipykernel_1092/13696829.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(day_of_month_landslides, kde=False, bins=31)
# <Axes: xlabel='date_parsed'>
